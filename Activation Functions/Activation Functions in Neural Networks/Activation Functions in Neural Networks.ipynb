# %% [markdown]
# An **activation function** is applied to the weighted sum of inputs before producing the final output of a neuron. It introduces non-linearity, allowing the network to learn complex patterns.

# %%
from PIL import Image
img = Image.open('Activation Functions in neural Networks.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1095x583>

# %% [markdown]
# - Applied after the weighted sum of inputs
# - Introduces non-linearity into the model
# - Enables learning of complex data patterns
# - Without it, the network behaves like a linear model

# %% [markdown]
# # Importance of Non-Linearity

# %% [markdown]
# ### Why Do We Need Non-Linear Functions?
#
# Real-world data is rarely **linearly separable**. Non-linear activation functions enable neural networks to learn and represent complex relationships that cannot be captured by a simple straight-line decision boundary.
#
# - They allow neural networks to create **curved and flexible decision boundaries**, making it possible to distinguish between classes with complex patterns (e.g., differentiating apples from bananas despite variations in color, size, and shape).
# - They enable networks to learn **non-linear relationships** present in real-world datasets.
# - They are essential for solving advanced tasks such as:
#   - **Image Recognition** (object and face detection)
#   - **Natural Language Processing (NLP)** (text classification, translation, chatbots)
#   - **Speech Recognition** (voice assistants and speech-to-text systems)
#
# Without non-linear functions, even deep neural networks would behave like a single linear model, severely limiting their learning capability.

# %% [markdown]
# ## Mathematical Example
#
# Consider a neural network with:
#
# - **Inputs:** \(i_1, i_2\)
# - **Hidden Layer:** Neurons \(h_1\) and \(h_2\)
# - **Output Layer:** One neuron (Output)
# - **Weights:** \(w_1, w_2, w_3, w_4, w_5, w_6\)
# - **Biases:** \(b_1\) for the hidden layer and \(b_2\) for the output layer

# %%
from PIL import Image
img = Image.open('Neural Network.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x493>

# %%
from PIL import Image
img = Image.open('Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1211x691>

# %% [markdown]
# # Types of Activation Functions in Deep Learning

# %% [markdown]
# ## 1. Linear Activation Function

# %% [markdown]
# Linear Activation Function resembles straight line define by y=x. No matter how many layers the neural network contains if they all use linear activation functions the output is a linear combination of the input.
# - The range of the output spans from
# (−∞ to +∞).
# - Output is a linear combination of inputs
# - Using it in all layers makes the network behave like a linear model
# - Limits the ability to learn complex patterns
# - Commonly used in the output layer for regression tasks
# - Often combined with non-linear functions in hidden layers for better learning

# %%
from PIL import Image
img = Image.open('Linear Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=747x557>

# %% [markdown]
# ## 2. Non-Linear Activation Functions

# %% [markdown]
# ### 1. Sigmoid Function

# %% [markdown]
# Sigmoid Activation Function is characterized by 'S' shape. It is mathematically defined as
# A = 1 / (1 + 1/e))
#
# 1
# ​
#  ​. This formula ensures a smooth and continuous output that is essential for gradient-based optimization methods.
#
# It allows neural networks to handle and model complex patterns that linear equations cannot.
# The output ranges between 0 and 1, hence useful for binary classification.
# The function exhibits a steep gradient when x values are between -2 and 2. This sensitivity means that small changes in input x can cause significant changes in output y which is critical during the training process.

# %%
from PIL import Image
img = Image.open('Sigmoid Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=798x542>

# %% [markdown]
# ### 2. Tanh Activation Function

# %%
from PIL import Image
img = Image.open('Tanh Activation Function 1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=812x313>

# %%
from PIL import Image
img = Image.open('Tanh Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=781x587>

# %% [markdown]
# ### 3. ReLU(Rectified Linear Unit)Function

# %% [markdown]
# ReLU activation is defined by A(x)=max(0,x), this means that if the input x is positive, ReLU returns x, if the input is negative, it returns 0.
# - Value Range is [0,∞), meaning the function only outputs non-negative values.
# - Introduces non-linearity, enabling learning of complex patterns
# - Computationally efficient due to simple operations
# - Activates only positive neurons, making the network sparse and efficient
# - Commonly used in hidden layers for faster training and better performance

# %%
from PIL import Image
img = Image.open('ReLU Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=772x571>

# %% [markdown]
# ### 4. Leaky ReLU

# %%
from PIL import Image
img = Image.open('Leaky ReLU Activation Function 1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=815x342>

# %%
from PIL import Image
img = Image.open('Leaky ReLU Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=852x642>

# %% [markdown]
# ### 5. SoftPlus Function

# %%
from PIL import Image
img = Image.open('Softplus Activation Function 1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=831x267>

# %%
from PIL import Image
img = Image.open('Softplus Activation Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=687x561>

# %% [markdown]
# ## 3. Exponential Linear Units
# ### 1. ELU (Exponential Linear Unit) Function

# %%
from PIL import Image
img = Image.open('ELU (Exponential Linear Unit) Function1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=837x342>

# %%
from PIL import Image
img = Image.open('ELU (Exponential Linear Unit) Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=792x541>

# %% [markdown]
# ### 2. SELU (Scaled Exponential Linear Unit) Function

# %%
from PIL import Image
img = Image.open('SELU (Scaled Exponential Linear Unit) Function1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=827x407>

# %%
from PIL import Image
img = Image.open('SELU (Scaled Exponential Linear Unit) Function.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=803x562>

# %% [markdown]
# ## 4. Output Layer Activation Functions
# ### 1. Sigmoid Activation Function

# %%
from PIL import Image
img = Image.open('Sigmoid Activation Function2.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=832x305>

# %%
from PIL import Image
img = Image.open('Sigmoid Activation Function3.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=827x573>

# %% [markdown]
# ### 2. Softmax Function

# %% [markdown]
# Softmax function is used for multi-class classification and converts raw output scores into probabilities for each class.
# - Transforms outputs into values between 0 and 1
# - Ensures all probabilities sum to 1
# - Highlights the most likely class among multiple options
# - Commonly used in the output layer for multi-class classification
# - Helps interpret model outputs as probabilities

# %%
from PIL import Image
img = Image.open('Softmax Activation Function3.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=803x612>

# %% [markdown]
# ### Impact of Activation Functions on Model Performance
# Activation functions play a key role in how efficiently a neural network learns and performs across different tasks.
# - ReLU helps in faster training by avoiding the vanishing gradient problem, while Sigmoid and Tanh can slow down convergence in deep networks
# - ReLU maintains better gradient flow, allowing deeper layers to learn effectively, whereas Sigmoid may produce very small gradients
# - Softmax enables handling of multi-class classification problems, while functions like ReLU or Leaky ReLU are commonly used in hidden layers for efficient learning
